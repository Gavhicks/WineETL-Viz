# %%
#Import Libraries
import pandas as pd
import datetime
from sqlalchemy import create_engine
# !pip install psycopg2-binary

# %%
#Read First Dataset
df1 = pd.read_csv("C:\\Users\\gavin_hicks\\Documents\\winemag-data_first150k.csv")
df1.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
#Read Second Dataset
df2 = pd.read_csv("C:\\Users\\gavin_hicks\\Documents\winemag-data-130k-v2.csv")
df2.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
#Drop Mismatched Columns
df2.drop(df2.columns[[0,9,10,11]],axis=1, inplace=True)
df2.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         variety               winery
# ...

# %%
#Drop Unnamed Column
df1.drop(df1.columns[[0]],axis=1, inplace=True)
df1.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
#Merge Files
df_list = [df1,df2]
df = pd.concat(df_list, ignore_index=True)
df
# Out:
#         country                                        description  \
# 0            US  This tremendous 100% varietal wine hails from ...
# 1         Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            US  Mac Watson honors the memory of a wine once ma...
# 3            US  This spent 20 months in 30% new French oak, an...
# 4        France  This is the top wine from La Bégude, named aft...
# ...         ...                                                ...
# 280896  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 280897       US  Citation is given as much as a decade of bottl...
# 280898   France  Well-drained gravel soil gives this wine its c...
# 280899   France  A dry style of Pinot Gris, this is crisp with ...
# 280900   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 0                            Martha's Vineyard      96  235.0      California
# ...

# %% [markdown]
# ## Data Cleaning

# %%
#Check for Duplicates (Using the description as it is most fitting unique identifier)
df.drop_duplicates(keep='first')
df
# Out:
#         country                                        description  \
# 0            US  This tremendous 100% varietal wine hails from ...
# 1         Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            US  Mac Watson honors the memory of a wine once ma...
# 3            US  This spent 20 months in 30% new French oak, an...
# 4        France  This is the top wine from La Bégude, named aft...
# ...         ...                                                ...
# 280896  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 280897       US  Citation is given as much as a decade of bottl...
# 280898   France  Well-drained gravel soil gives this wine its c...
# 280899   France  A dry style of Pinot Gris, this is crisp with ...
# 280900   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 0                            Martha's Vineyard      96  235.0      California
# ...

# %% [markdown]
# 110,370 Duplicates Removes

# %%
#Check for Blanks
df.isnull().sum()
# Out:
# country            68
# description         0
# designation     83200
# points              0
# price           22691
# province           68
# region_1        46307
# region_2       169437
# variety             1
# winery              0
# dtype: int64

# %%
#Showing as a % so that I can identify next best action (Drop or Impute)
(df.isnull().sum() / df.shape[0]) * 100
# Out:
# country         0.024208
# description     0.000000
# designation    29.618976
# points          0.000000
# price           8.077935
# province        0.024208
# region_1       16.485167
# region_2       60.319116
# variety         0.000356
# winery          0.000000
# dtype: float64

# %% [markdown]
# For Null% above 30%, I will drop the column = Region_2
# <30%, I will try to impute.

# %%
#Drop Region_2
df.drop(df.columns[[2,7]],axis=1, inplace=True)
df
# Out:
#         country                                        description  points  \
# 0            US  This tremendous 100% varietal wine hails from ...      96
# 1         Spain  Ripe aromas of fig, blackberry and cassis are ...      96
# 2            US  Mac Watson honors the memory of a wine once ma...      96
# 3            US  This spent 20 months in 30% new French oak, an...      96
# 4        France  This is the top wine from La Bégude, named aft...      95
# ...         ...                                                ...     ...
# 280896  Germany  Notes of honeysuckle and cantaloupe sweeten th...      90
# 280897       US  Citation is given as much as a decade of bottl...      90
# 280898   France  Well-drained gravel soil gives this wine its c...      90
# 280899   France  A dry style of Pinot Gris, this is crisp with ...      90
# 280900   France  Big, rich and off-dry, this is powered by inte...      90
#
# ...

# %%
#Iterate through Null columns < 30
#Country
df[df['country'].isnull()]
# Out:
#        country                                        description  points  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...      90
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...      90
# 68226      NaN  From first sniff to last, the nose never makes...      81
# 113016     NaN  From first sniff to last, the nose never makes...      81
# 135696     NaN  From first sniff to last, the nose never makes...      81
# ...        ...                                                ...     ...
# 275106     NaN  This Swiss red blend is composed of four varie...      90
# 280337     NaN  Dry spicy aromas of dusty plum and tomato add ...      89
# 280338     NaN  El Capricho is one of Uruguay's more consisten...      89
# 280520     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...      90
# 280830     NaN  This wine offers a delightful bouquet of black...      91
#
#         price province region_1             variety             winery
# ...

# %%
#Chilcas
df[df['winery'] == 'Chilcas']
# Out:
#        country                                        description  points  \
# 19598    Chile  Neutral up front except for green apple and mi...      88
# 19773    Chile  Dark up front, with aromas of charcoal and cru...      87
# 20267    Chile  Crisp apple aromas are light and minerally. Fe...      86
# 20517    Chile  Full in style, with sweet aromas of black frui...      85
# 30258    Chile  Jammy blackberry and plum aromas come with hin...      85
# ...        ...                                                ...     ...
# 273608   Chile  Apple and melony aromas rule the easygoing, tr...      88
# 277329   Chile  Despite showing a note of vinegar on the nose,...      86
# 278083   Chile  Not overtly green smelling, but thisdeals herb...      83
# 278574   Chile  A bit of heat oozes off the bouquet, but it's ...      90
# 279010   Chile  Earthy aromas of leather, coffee grounds and b...      89
#
#         price           province region_1                   variety   winery
# ...

# %%
#Replace Chilcas NaN with Chile
df.loc[df['winery'] == 'Chilcas', 'country'] = 'Chile'

# %% [markdown]
# Iterating through the different wineries to determine the correct country would be quite a tedious effort.
# In the interest of efficiency, I will create a new dataframe with Country, Variety & Winery combinations for the
# purpose of acting as a dimension table in the PostgreSQL database

# %%
ctry_df = df[["country","variety","winery","province"]]
ctry_df.drop_duplicates().reset_index(drop=True)
# Out:
#            country             variety                   winery  \
# 0               US  Cabernet Sauvignon                    Heitz
# 1            Spain       Tinta de Toro  Bodega Carmen Rodríguez
# 2               US     Sauvignon Blanc                 Macauley
# 3               US          Pinot Noir                    Ponzi
# 4           France  Provence red blend     Domaine de la Bégude
# ...            ...                 ...                      ...
# 55281           US        Chenin Blanc                Birichino
# 55282           US           Zinfandel                  Houdini
# 55283  New Zealand     Cabernet Merlot               Mills Reef
# 55284  New Zealand          Pinot Gris                      Ara
# 55285        Italy            Frappato                      COS
#
#                 province
# 0             California
# 1         Northern Spain
# 2             California
# 3                 Oregon
# 4               Provence
# ...                  ...
# ...

# %%
#Write DataFrame to Postgres Table
engine = create_engine('postgresql://gavin:project@localhost:5432/winery')
ctry_df.to_sql('ctrydt',engine)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [84], in <cell line: 2>()
#       1 #Write DataFrame to Postgres Table
# ----> 2 engine = create_engine('postgresql://gavin:project@localhost:5432/winery')
#       3 ctry_df.to_sql('ctrydt',engine)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py:560, in create_engine(url, **kwargs)
#     558         if k in kwargs:
# ...
